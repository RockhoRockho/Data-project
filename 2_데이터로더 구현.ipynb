# %%
'''
# https://www.tensorflow.org/api_docs/python/tf/keras/utils/Sequence

def __init__(self, x_set, y_set, batch_size):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) *
        self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) *
        self.batch_size]

        return np.array([
            resize(imread(file_name), (200, 200))
               for file_name in batch_x]), np.array(batch_y)

'''
pass

# %%
import math
import random
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow import keras

# %%
# !pip install tensorflow # GPU
# !pip install tensorflow-cpu
# Out:
# Requirement already satisfied: tensorflow-cpu in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (2.7.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (2.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (0.37.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.42.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (12.0.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (3.19.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (0.22.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.13.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.1.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (2.7.0)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (1.21.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (4.0.1)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (2.7.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-cpu) (3.6.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (49.2.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from tensorboard~=2.6->tensorflow-cpu) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu) (4.8)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow-cpu) (4.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu) (2021.10.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow-cpu) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.6->tensorflow-cpu) (3.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow-cpu) (3.1.1)
# WARNING: You are using pip version 20.2.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self, batch_size, csv_path,
                 fold, image_size, mode='train', shuffle=True):
        self.batch_size = batch_size
        self.fold = fold
        self.image_size = image_size
        self.mode = mode
        self.shuffle = shuffle
        
        self.df = pd.read_csv(csv_path)
        
        if self.mode == 'train':
            self.df = self.df[self.df['fold'] != self.fold]
        elif self.mode == 'val':
            self.df = self.df[self.df['fold'] == self.fold]
            
        self.on_epoch_end() # 훈련 중 epoch 끝날 때 호출
        '''
        keras.utils.Sequence
            def on_epoch_end(self, epoch):
        '''
    
    # sample() : 전체 row에서 몇 %의 데이터를 return 할 것인지 설정
    # reset_index() : drop=True 옵션을 지정하면 인덱스 열을 보통의 자료열로 올리는
    # 것이 아니라 버림
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
        
    def __len__(self):
        return math.ceil(len(self.df) / self.batch_size)
    
    def __getitem__(self, idx):
        strt = idx * self.batch_size
        fin = (idx + 1) * self.batch_size
        data = self.df.iloc[strt:fin]
        batch_x, batch_y = self.get_data(data)
        
        return np.array(batch_x), np.array(batch_y)
        
    
    def get_data(self, data):
        batch_x = []
        batch_y = []
        
        for _, r in data.iterrows():
            file_name = r['file_name']
            image = cv2.imread(f'data/images/{file_name}.jpg')
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (self.image_size, self.image_size))
            image = image / 255.
            
            label = int(r['species']) - 1
            
            batch_x.append(image)
            batch_y.append(label)
        
        return batch_x, batch_y

# %%
csv_path = 'data/kfolds.csv'

# __init__(self, batch_size, csv_path, fold, image_size, mode='train', shuffle=True)
train_generator = DataGenerator(
    batch_size = 9,
    csv_path = csv_path,
    fold = 1,
    image_size = 256,
    mode = 'train',
    shuffle = True
)

# %%
print(len(train_generator))
# Out:
# 654

# %%
654 * 9
# Out:
# 5886

# %%
class_name = ['Cat', 'Dog']

for batch in train_generator:
    X, y = batch
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(X[i])
        plt.title(class_name[y[i]])
        plt.axis('off')
    break
